# %%
import os
import torch
from transformers import WhisperForConditionalGeneration, WhisperProcessor
from transformers import pipeline

# %%
def fix_right_to_left(text):
    return text.replace(r"\u20b","\n")

# %%
#load huggingface/pytorch model from models/whisper-small and push to hub


#load model
# model = WhisperForConditionalGeneration.from_pretrained("models/whisper-small")
# processor = WhisperProcessor.from_pretrained("models/whisper-small")

#push model to hub
# model.push_to_hub("whisper-small")
# processor.push_to_hub("whisper-small")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
local_pipeline = pipeline(model="Shuaf98/whisper-small")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
#load test_data
from datasets import load_from_disk

test_data = load_from_disk('datasets/kan_dataset/test')
from IPython.display import Audio
sample = test_data[5]['audio']
#display audio
Audio(sample["array"], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#get inference from a sample
local_pipeline(sample['array'], generate_kwargs={"language":"Hebrew"})
# Out:
# {'text': ' \u202bהם ראה לי תקשיב לא ידעו שהייתי בעיון \u202bופתאום לבוא עם ירד מוכן.'}

# %%
whisper_pipeline = pipeline(model="openai/whisper-small")
pred = whisper_pipeline(sample["array"], generate_kwargs={"language":"Hebrew"})['text']

#print pred, but make every \u20b a new line
print(pred.replace(

# %%
pred.replace(r"\u20b","\n")
# Out:
# ' \u202bהם ראה לי תקשיב, \u202bלא ידעו שהייתי בעיון, \u202bופתאום לבוא עם ירד מוכן.'
